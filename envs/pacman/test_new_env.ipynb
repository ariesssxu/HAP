# %%
from envs import PacmanEnv
import matplotlib.pyplot as plt
import numpy as np
import gym

# %%
env = PacmanEnv(render_mode='rgb_array')
env.reset()
# render and show
img = env.render()
print(img.shape)
plt.imshow(img)

# remove axis
plt.axis('off')
# plt.savefig('empty_env.pdf', bbox_inches='tight')
# Out:
# (576, 448, 3)
# (np.float64(-0.5), np.float64(447.5), np.float64(575.5), np.float64(-0.5))

# %%
# %load_ext autoreload
# %autoreload 2

env = PacmanEnv(render_mode='rgb_array', level=1)
env.reset()
# render and show
img = env.render()
print(img.shape)
plt.imshow(img)

# remove axis
plt.axis('off')
# plt.savefig('empty_env.pdf', bbox_inches='tight')
# Out:
# (576, 448, 3)
# (np.float64(-0.5), np.float64(447.5), np.float64(575.5), np.float64(-0.5))

# %%
env = PacmanEnv(render_mode='rgb_array', level = 2)
env.reset()
# render and show
img = env.render()
print(img.shape)
plt.imshow(img)

# remove axis
plt.axis('off')
# plt.savefig('empty_env.pdf', bbox_inches='tight')
# Out:
# (576, 448, 3)
# (np.float64(-0.5), np.float64(447.5), np.float64(575.5), np.float64(-0.5))

# %%
env = PacmanEnv(render_mode='rgb_array', level = 3)
env.reset()
env.step(1)
# render and show
img = env.render()
print(img.shape)
plt.imshow(img)

# remove axis
plt.axis('off')
# plt.savefig('empty_env.pdf', bbox_inches='tight')
# Out:
# (576, 448, 3)
# (np.float64(-0.5), np.float64(447.5), np.float64(575.5), np.float64(-0.5))

# %%
env = PacmanEnv(render_mode='rgb_array', level = 4)
env.reset()
# render and show
img = env.render()
print(img.shape)
plt.imshow(img)

# remove axis
plt.axis('off')
# plt.savefig('empty_env.pdf', bbox_inches='tight')
# Out:
# (576, 448, 3)
# (np.float64(-0.5), np.float64(447.5), np.float64(575.5), np.float64(-0.5))

# %%
env = PacmanEnv(render_mode='rgb_array', level = 5)
env.reset()
# env.step(1)
# render and show
img = env.render()
print(img.shape)
plt.imshow(img)

# remove axis
plt.axis('off')
# plt.savefig('empty_env.pdf', bbox_inches='tight')
# Out:
# (576, 448, 3)
# (np.float64(-0.5), np.float64(447.5), np.float64(575.5), np.float64(-0.5))
